# %% [markdown]
# <a href="https://colab.research.google.com/github/aorceradw/ENTORNOS-DE-DESARROLLO-/blob/main/prueba_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hola...probando brobando")
